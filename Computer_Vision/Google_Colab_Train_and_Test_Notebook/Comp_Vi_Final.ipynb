# %% [markdown]
# Train and test notebook!

# %%
# !unzip Computer_Vision.zip
# Out:
# Archive:  Computer_Vision.zip
#    creating: Computer_Vision/
#    creating: Computer_Vision/Computer_Vision/
#    creating: Computer_Vision/Computer_Vision/.ipynb_checkpoints/
#    creating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/
#   inflating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/data.yaml
#   inflating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/README.dataset.txt
#   inflating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/README.roboflow.txt
#    creating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/test/
#   inflating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/test/ppe_0000_jpg.rf.c102a9a7c8dec01565a8f95ff295974c.jpg
#   inflating: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/test/ppe_0000_jpg.rf.c102a9a7c8dec01565a8f95ff295974c.txt
# ...

# %%
import os
   os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
# Out:
#   File "<ipython-input-7-cc2e75655fbf>", line 2
#     os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
#     ^
# IndentationError: unexpected indent

# %%
# !python ./Computer_Vision/yolov5/train.py --img 640 --batch 64 --epochs 100 --data "./Computer_Vision/construction safety.v2-release.darknet/data.yaml" --weights ./Computer_Vision/yolov5/yolov5s.pt --hyp ./Computer_Vision/yolov5/data/hyps/hyp.scratch-low.yaml --name yolov5s_ppe_finetuned_darknet_structure --project ./Computer_Vision/models_training_runs
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-11 17:39:48.713399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746985188.746465    9266 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746985188.756586    9266 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: hieutx-22bi13163 (hieutx-22bi13163-usth) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# ...

# %%
# !zip -r ./Computer_Vision.zip ./Computer_Vision
# Out:
#   adding: Computer_Vision/ (stored 0%)
#   adding: Computer_Vision/webcam_tracking.py (deflated 61%)
#   adding: Computer_Vision/val_dataset_filter.py (deflated 54%)
#   adding: Computer_Vision/object_dection.py (deflated 45%)
#   adding: Computer_Vision/video_tracking.py (deflated 60%)
#   adding: Computer_Vision/FINAL REPORT.pdf (deflated 14%)
#   adding: Computer_Vision/train_dataset_filter.py (deflated 54%)
#   adding: Computer_Vision/FINAL REPORT.docx (deflated 2%)
#   adding: Computer_Vision/Computer_Vision/ (stored 0%)
#   adding: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/ (stored 0%)
#   adding: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/train.cache (deflated 60%)
#   adding: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/data.yaml (deflated 51%)
#   adding: Computer_Vision/Computer_Vision/construction safety.v2-release.darknet/valid/ (stored 0%)
# ...

# %%
# !python ./Computer_Vision/Computer_Vision/src/main_app.py
# Out:
# Attempting to process video: /content/Computer_Vision/Computer_Vision/sample_videos/video_test.mp4
# Using model: /content/Computer_Vision/Computer_Vision/models/best.pt
# Output will be saved to: /content/Computer_Vision/Computer_Vision/output_videos/output_ppe_compliance_colab.mp4
# Using device: cuda
# DEBUG: Resolved absolute model weights path: /content/Computer_Vision/Computer_Vision/models/best.pt
# DEBUG: YOLOv5 repository path: /content/Computer_Vision/Computer_Vision/yolov5
# DEBUG: Changed CWD to: /content/Computer_Vision/Computer_Vision/yolov5
# Attempting to load custom model: /content/Computer_Vision/Computer_Vision/models/best.pt
# YOLOv5 🚀 v7.0-418-ga493afe1 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# YOLOv5 custom model loaded successfully using CWD '/content/Computer_Vision/Computer_Vision/yolov5'.
# ...
